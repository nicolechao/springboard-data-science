# %% [markdown]
# # Hospital Readmissions Data Analysis and Recommendations for Reduction
#
# ### Background
# In October 2012, the US government's Center for Medicare and Medicaid Services (CMS) began reducing Medicare payments for Inpatient Prospective Payment System hospitals with excess readmissions. Excess readmissions are measured by a ratio, by dividing a hospital’s number of “predicted” 30-day readmissions for heart attack, heart failure, and pneumonia by the number that would be “expected,” based on an average hospital with similar patients. A ratio greater than 1 indicates excess readmissions.
#
# ### Exercise Directions
#
# In this exercise, you will:
# + critique a preliminary analysis of readmissions data and recommendations (provided below) for reducing the readmissions rate
# + construct a statistically sound analysis and make recommendations of your own
#
# More instructions provided below. Include your work **in this notebook and submit to your Github account**.
#
# ### Resources
# + Data source: https://data.medicare.gov/Hospital-Compare/Hospital-Readmission-Reduction/9n3s-kdb3
# + More information: http://www.cms.gov/Medicare/medicare-fee-for-service-payment/acuteinpatientPPS/readmissions-reduction-program.html
# + Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
# ****

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bokeh.plotting as bkp
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable

sns.set()
sns.set_style("whitegrid")
palette = sns.diverging_palette(220, 20, sep = 20, n = 20)
sns.set_palette(palette)

# %%
# read in readmissions data provided
hospital_read_df = pd.read_csv('data/cms_hospital_readmissions.csv')
hospital_read_df.head()
# Out:
#                                Hospital Name  Provider Number State  \
# 0       FROEDTERT MEMORIAL LUTHERAN HOSPITAL           520177    WI
# 1                        PROVIDENCE HOSPITAL            90006    DC
# 2          BEAUFORT COUNTY MEMORIAL HOSPITAL           420067    SC
# 3  ADVOCATE CHRIST HOSPITAL & MEDICAL CENTER           140208    IL
# 4          BRAZOSPORT REGIONAL HEALTH SYSTEM           450072    TX
#
#              Measure Name Number of Discharges  Footnote  \
# 0  READM-30-HIP-KNEE-HRRP                  242       NaN
# 1  READM-30-HIP-KNEE-HRRP                  247       NaN
# 2  READM-30-HIP-KNEE-HRRP                  586       NaN
# 3  READM-30-HIP-KNEE-HRRP                  965       NaN
# 4  READM-30-HIP-KNEE-HRRP                  149       NaN
#
#    Excess Readmission Ratio  Predicted Readmission Rate  \
# 0                    1.9095                        10.8
# 1                    1.7521                         9.2
# ...

# %% [markdown]
# ****
# ## Preliminary Analysis

# %%
# deal with missing and inconvenient portions of data 
clean_hospital_read_df = hospital_read_df[hospital_read_df['Number of Discharges'] != 'Not Available']
clean_hospital_read_df.loc[:, 'Number of Discharges'] = clean_hospital_read_df['Number of Discharges'].astype(int)
clean_hospital_read_df = clean_hospital_read_df.sort_values('Number of Discharges')
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
clean_hospital_read_df.head()
# Out:
#                               Hospital Name  Provider Number State  \
# 16857           THREE RIVERS MEDICAL CENTER           180128    KY
# 14582  SELLS INDIAN HEALTH SERVICE HOSPITAL            30074    AZ
# 15606     PHS INDIAN HOSPITAL AT PINE RIDGE           430081    SD
# 15615    FLORIDA STATE HOSPITAL UNIT 31 MED           100298    FL
# 14551                GREENE COUNTY HOSPITAL            10051    AL
#
#                  Measure Name  Number of Discharges  Footnote  \
# 16857  READM-30-HIP-KNEE-HRRP                     0       7.0
# 14582      READM-30-COPD-HRRP                     0       7.0
# 15606       READM-30-AMI-HRRP                     0       7.0
# 15615      READM-30-COPD-HRRP                     0       7.0
# 14551       READM-30-AMI-HRRP                     0       7.0
#
#        Excess Readmission Ratio  Predicted Readmission Rate  \
# 16857                       NaN                         NaN
# 14582                       NaN                         NaN
# ...

# %%
clean_hospital_read_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11578 entries, 16857 to 13666
# Data columns (total 12 columns):
# Hospital Name                 11578 non-null object
# Provider Number               11578 non-null int64
# State                         11578 non-null object
# Measure Name                  11578 non-null object
# Number of Discharges          11578 non-null int64
# Footnote                      81 non-null float64
# Excess Readmission Ratio      11497 non-null float64
# Predicted Readmission Rate    11497 non-null float64
# Expected Readmission Rate     11497 non-null float64
# Number of Readmissions        11497 non-null float64
# Start Date                    11578 non-null object
# End Date                      11578 non-null object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
# generate a scatterplot for number of discharges vs. excess rate of readmissions
# lists work better with matplotlib scatterplot function
x = [a for a in clean_hospital_read_df['Number of Discharges'][81:-3]]
y = list(clean_hospital_read_df['Excess Readmission Ratio'][81:-3])

fig, ax = plt.subplots(figsize=(8,5))
ax.scatter(x, y, alpha=0.2)

ax.fill_between([0,350], 1.15, 2, facecolor='red', alpha = .15, interpolate=True)
ax.fill_between([800,2500], .5, .95, facecolor='green', alpha = .15, interpolate=True)

ax.set_xlim([0, max(x)])
ax.set_xlabel('Number of discharges', fontsize=12)
ax.set_ylabel('Excess rate of readmissions', fontsize=12)
ax.set_title('Scatterplot of number of discharges vs. excess rate of readmissions', fontsize=14)

ax.grid(True)
fig.tight_layout()

# %% [markdown]
# ****
#
# ## Preliminary Report
#
# Read the following results/report. While you are reading it, think about if the conclusions are correct, incorrect, misleading or unfounded. Think about what you would change or what additional analyses you would perform.
#
# **A. Initial observations based on the plot above**
# + Overall, rate of readmissions is trending down with increasing number of discharges
# + With lower number of discharges, there is a greater incidence of excess rate of readmissions (area shaded red)
# + With higher number of discharges, there is a greater incidence of lower rates of readmissions (area shaded green)
#
# **B. Statistics**
# + In hospitals/facilities with number of discharges < 100, mean excess readmission rate is 1.023 and 63% have excess readmission rate greater than 1
# + In hospitals/facilities with number of discharges > 1000, mean excess readmission rate is 0.978 and 44% have excess readmission rate greater than 1
#
# **C. Conclusions**
# + There is a significant correlation between hospital capacity (number of discharges) and readmission rates.
# + Smaller hospitals/facilities may be lacking necessary resources to ensure quality care and prevent complications that lead to readmissions.
#
# **D. Regulatory policy recommendations**
# + Hospitals/facilties with small capacity (< 300) should be required to demonstrate upgraded resource allocation for quality care to continue operation.
# + Directives and incentives should be provided for consolidation of hospitals and facilities to have a smaller number of them with higher capacity and number of discharges.

# %% [markdown]
# ****
# ### Exercise
#
# Include your work on the following **in this notebook and submit to your Github account**.
#
# A. Do you agree with the above analysis and recommendations? Why or why not?
#
# B. Provide support for your arguments and your own recommendations with a statistically sound analysis:
#
#    1. Setup an appropriate hypothesis test.
#    2. Compute and report the observed significance value (or p-value).
#    3. Report statistical significance for $\alpha$ = .01.
#    4. Discuss statistical significance and practical significance. Do they differ here? How does this change your recommendation to the client?
#    5. Look at the scatterplot above.
#       - What are the advantages and disadvantages of using this plot to convey information?
#       - Construct another plot that conveys the same information in a more direct manner.
#
#
#
# You can compose in notebook cells using Markdown:
# + In the control panel at the top, choose Cell > Cell Type > Markdown
# + Markdown syntax: http://nestacms.com/docs/creating-content/markdown-cheat-sheet
# ****

# %% [markdown]
# ### Data Cleaning

# %%
clean_hospital_read_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11578 entries, 16857 to 13666
# Data columns (total 12 columns):
# Hospital Name                 11578 non-null object
# Provider Number               11578 non-null int64
# State                         11578 non-null object
# Measure Name                  11578 non-null object
# Number of Discharges          11578 non-null int64
# Footnote                      81 non-null float64
# Excess Readmission Ratio      11497 non-null float64
# Predicted Readmission Rate    11497 non-null float64
# Expected Readmission Rate     11497 non-null float64
# Number of Readmissions        11497 non-null float64
# Start Date                    11578 non-null object
# End Date                      11578 non-null object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
clean_hospital_read_df = clean_hospital_read_df.dropna(subset=['Number of Readmissions'])
clean_hospital_read_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11497 entries, 1832 to 13666
# Data columns (total 12 columns):
# Hospital Name                 11497 non-null object
# Provider Number               11497 non-null int64
# State                         11497 non-null object
# Measure Name                  11497 non-null object
# Number of Discharges          11497 non-null int64
# Footnote                      0 non-null float64
# Excess Readmission Ratio      11497 non-null float64
# Predicted Readmission Rate    11497 non-null float64
# Expected Readmission Rate     11497 non-null float64
# Number of Readmissions        11497 non-null float64
# Start Date                    11497 non-null object
# End Date                      11497 non-null object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
x = [a for a in clean_hospital_read_df['Number of Discharges']]
y = list(clean_hospital_read_df['Excess Readmission Ratio'])

# %% [markdown]
# ### A. Do you agree with the above analysis and recommendations? Why or why not?

# %% [markdown]
# I do not agree as the above analysis & recommendations are purely based on scattered plot. I would like to analyze more w/ statistical thinking before coming to conclusions.

# %% [markdown]
# ### B. Provide support for your arguments and your own recommendations with a statistically sound analysis:

# %% [markdown]
# #### 1. Setup an appropriate hypothesis test.
# **Null Hypothesis**: There is a relationship between number of discharges and excess of re-admission.
#
#
# **Alternate hypothesis**: there is no relationship between the number of discharges and excess of re-admission.
#
# Test Statistic: Pearson correlation coefficient, ρ, between number of discharges & excess rate of readmissions.

# %% [markdown]
# #### 2. Compute and report the observed significance value (or p-value).

# %%
# define function for calculate pearson correlation, ρ
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    corr_mat = np.corrcoef(x, y)
    return corr_mat[0,1]

# Compute observed correlation: r_obs
r_obs = pearson_r(x, y)
print(r_obs)
# Out:
# -0.0973979435108

# %%
# Initialize permutation replicates: perm_replicates
perm_replicates = np.empty(10000)

# Draw replicates
for i in range(10000):
    # Permute illiteracy measurments: illiteracy_permuted
    x_permuted = np.random.permutation(x)

    # Compute Pearson correlation
    perm_replicates[i] = pearson_r(x_permuted, y)

# Compute p-value: p
p = np.sum(perm_replicates <= r_obs) / len(perm_replicates)
print('p-value: ', p)
# Out:
# p-value:  0.0

# %%
from scipy.stats import pearsonr
correlation, p = pearsonr(x, y)
print('correlation: ', correlation)
print('p-value: ', p)
# Out:
# correlation:  -0.0973979435108
# p-value:  1.22254737768e-25

# %% [markdown]
# ### 3. Report statistical significance for $\alpha$ = .01.

# %%
alpha = 0.01
if p < alpha:
    print('p-value is less than 0.01.')
else:
    print('p-value is equal or more than than 0.01.')
# Out:
# p-value is less than 0.01.

# %% [markdown]
# p value of all tests are less than alpha. We can reject the null hypothesis.
# Therefore, there is **no** correlation between number of discharges & excess rate of readmissions.

# %% [markdown]
# #### 4. Discuss statistical significance and practical significance. Do they differ here? How does this change your recommendation to the client?

# %% [markdown]
# > **B. Statistics**
# + In hospitals/facilities with number of discharges < 100, mean excess readmission rate is 1.023 and 63% have excess readmission rate greater than 1
# + In hospitals/facilities with number of discharges > 1000, mean excess readmission rate is 0.978 and 44% have excess readmission rate greater than 1

# %% [markdown]
# Let's consider by hospitals/facilities with number of discharges < 100 vs. hospitals/facilities with number of discharges > 1000 as in the above analysis they were discussed:

# %%
df_less_than_100 = clean_hospital_read_df[clean_hospital_read_df['Number of Discharges'] < 100]
x = [a for a in df_less_than_100['Number of Discharges']]
y = list(df_less_than_100['Excess Readmission Ratio'])
correlation, p = pearsonr(x, y)
print('correlation: ', correlation)
print('p-value: ', p)
# Out:
# correlation:  -0.244635500335
# p-value:  1.19559278455e-17

# %%
sns.jointplot('Number of Discharges', 'Excess Readmission Ratio', data = df_less_than_100, kind = 'reg')

# %%
df_more_than_1000 = clean_hospital_read_df[clean_hospital_read_df['Number of Discharges'] > 1000]
x = [a for a in df_more_than_1000['Number of Discharges']]
y = list(df_more_than_1000['Excess Readmission Ratio'])
correlation, p = pearsonr(x, y)
print('correlation: ', correlation)
print('p-value: ', p)
# Out:
# correlation:  -0.0792766567904
# p-value:  0.0883994417706

# %%
sns.jointplot('Number of Discharges', 'Excess Readmission Ratio', data = df_more_than_1000, kind = 'reg')

# %% [markdown]
# > #### Discuss statistical significance and practical significance. Do they differ here?
#
# * For hospitals/facilities with number of discharges < 100, as p-value is less than $\alpha$ = .01, it seems there's no correlation between number of discharges & excess rate of readmissions.
# * While for hospitals/facilities with number of discharges > 1000,  as p-value is greater than $\alpha$ = .01, it seems there is correlation between number of discharges & excess rate of readmissions.
# * We can conclude that statistical significance and practical significance do differ here.

# %% [markdown]
# #### How does this change your recommendation to the client?
# #### Conclusion:
#   * p-value is different under different scenarios.
#   * There is a significant correlation between hospital capacity (number of discharges) and readmission ratesm when number of discharges is larger than 1000.
#   * But for smaller hospitals/facilities, there's no statistical clue for the same conclusion.
#
# #### Recommendations:
# Since for small capacity hospitals/facilities, there's no correlation between number of discharges & excess rate of readmissions, I would recommned to explore more features which might be able to correlate with excess rate of readmissions.

# %% [markdown]
# #### 5. Look at the scatterplot above.
# > - What are the advantages and disadvantages of using this plot to convey information?
#
# A scatter plot is very good for visulization relation of two features but when data points do not have a clear trend, it would be better apply inferential statistics.

# %% [markdown]
# > * Construct another plot that conveys the same information in a more direct manner.
#
# Let's split the dataset into 10-evenly sized groups in sorted order from least to most number of discharges.

# %%
pct = np.percentile(sorted(clean_hospital_read_df['Number of Discharges']), range(5, 105, 5))
print(pct)

def group_by_n_discharges(x):
    group = 0
    lastP = 0
    for i, p in enumerate(pct):
        if x > lastP and x <= p:
            group = i + 1
            break
        lastP = p
    return group
        
clean_hospital_read_df['Number of Discharges Group'] = clean_hospital_read_df['Number of Discharges'].apply(group_by_n_discharges)
# Out:
# [   76.     98.    117.    138.    160.    181.8   204.    228.    254.
#    282.    310.    344.    380.    423.    474.    534.    609.6   726.4
#    931.   6793. ]

# %%
def get_sub_plot(width = 20, height = 10, label_font_size = 14, tick_font_size = 13):
    fig, ax = plt.subplots()
    fig.set_size_inches(width, height)
    ax.tick_params(labelsize = tick_font_size)
    ax.set_xlabel(ax.get_xlabel(), fontsize = label_font_size)
    ax.set_ylabel(ax.get_ylabel(), fontsize = label_font_size)
    return ax

ax = get_sub_plot()
sns.violinplot(x = 'Number of Discharges Group', y = 'Excess Readmission Ratio', data = clean_hospital_read_df, ax = ax)

# %%
clean_hospital_read_df_grouped = clean_hospital_read_df.groupby('Number of Discharges Group').aggregate(np.mean).reset_index()
clean_hospital_read_df_grouped[['Number of Discharges Group', 'Excess Readmission Ratio']]
# Out:
#     Number of Discharges Group  Excess Readmission Ratio
# 0                            1                  1.034201
# 1                            2                  1.011915
# 2                            3                  1.008802
# 3                            4                  1.011591
# 4                            5                  1.013414
# 5                            6                  1.015068
# 6                            7                  1.006849
# 7                            8                  1.014619
# 8                            9                  1.018226
# 9                           10                  1.011750
# 10                          11                  1.007868
# 11                          12                  1.006880
# 12                          13                  1.004859
# 13                          14                  0.998233
# 14                          15                  1.002440
# ...

# %%
ax = get_sub_plot()
sns.barplot(x = 'Number of Discharges Group', y = 'Excess Readmission Ratio', data = clean_hospital_read_df_grouped, ax = ax)

# %% [markdown]
# Based on the boxplot above, we can see that with the data points evenly-distributed, when number of discharges increases, the range of readmissions also increases. If we further plot the mean for each group in a barplot we can see that the mean of readmission ratio started to decrease only at the last group.
#
# If we revisit what't the last group of 'Number of Discharges', we can see that it's between 931 to 6793.

# %%
pct = np.percentile(sorted(clean_hospital_read_df['Number of Discharges']), range(5, 105, 5))
print(pct)
# Out:
# [   76.     98.    117.    138.    160.    181.8   204.    228.    254.
#    282.    310.    344.    380.    423.    474.    534.    609.6   726.4
#    931.   6793. ]

# %% [markdown]
# It somewhat matched what we found previously, that when number of discharges > 1000, as p-value is greater than  α  = .01, it seems there is correlation between number of discharges & excess rate of readmissions.
#
# We can verify by only look at data w/ number of discharges > 1000:

# %%
pct = np.percentile(sorted(df_more_than_1000['Number of Discharges']), range(10, 110, 10))
print(pct)

df_more_than_1000['Number of Discharges Group'] = df_more_than_1000['Number of Discharges'].apply(group_by_n_discharges)
sns.violinplot(x = 'Number of Discharges Group', y = 'Excess Readmission Ratio', data = df_more_than_1000, ax = ax)
# Out:
# [ 1043.4  1088.4  1121.6  1170.8  1242.   1350.2  1452.8  1587.2  1845.8
#   6793. ]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_more_than_1000_grouped = df_more_than_1000.groupby('Number of Discharges Group').aggregate(np.mean).reset_index()
df_more_than_1000_grouped[['Number of Discharges Group', 'Excess Readmission Ratio']]
# Out:
#    Number of Discharges Group  Excess Readmission Ratio
# 0                           1                  0.971355
# 1                           2                  0.975670
# 2                           3                  1.001165
# 3                           4                  0.989983
# 4                           5                  0.966717
# 5                           6                  0.987462
# 6                           7                  0.985446
# 7                           8                  0.990737
# 8                           9                  0.958746
# 9                          10                  0.957385

# %%
ax = get_sub_plot()
sns.barplot(x = 'Number of Discharges Group', y = 'Excess Readmission Ratio', data = df_more_than_1000_grouped, ax = ax)

# %% [markdown]
# And yes, based on the barplot above. When number of discharges > 1000, there is correlation between number of discharges & excess rate of readmissions.

# %% [markdown]
# So let's revisit the 1st question:
#
# > ### A. Do you agree with the above analysis and recommendations? Why or why not?
#
# No I don't agree because after all the statistical analysis. The reasons are:
# 1. For null hypothesis that there is a relationship between number of discharges and excess of re-admission, we reject it because p value of all tests are less than alpha.
# 2. We also compared hospitals/facilities with number of discharges < 100 vs. hospitals/facilities with number of discharges > 1000 & found that p-value is different under different scenarios. There is a significant correlation between hospital capacity (number of discharges) and readmission ratesm when number of discharges is larger than 1000.
# But for smaller hospitals/facilities, there's no statistical clue for the same conclusion.
# 3. We also plot the mean of evenly-splitted data sorted by number of discharges and showed that there's indeed no correlation when number of discharges is small.
# 4. We also plot the mean of evenly-splitted data for sorted by number of discharges for hospitals/facilities with number of discharges > 1000 and showed that there's indeed correlation when number of discharges is > 1000.
#
# Therefore, my recommendation:
#
#
# Since for small capacity hospitals/facilities, there's no correlation between number of discharges & excess rate of readmissions, I would recommned to explore more features which might be able to correlate with excess rate of readmissions.
