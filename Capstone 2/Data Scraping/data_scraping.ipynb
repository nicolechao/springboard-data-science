# %% [markdown]
# # Data Scraping
#
# In this notebook we
# 1. Use Selenium & twitter search API to scrape twitter data.
# 2. Dump them in to a csv file for further analysis.

# %%
# Import packages
import pandas as pd
import json

# selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
# Define function for scraping tweets
class Scraper():
    driver_path = "/Users/Nicole/Courses/Springboard-data-science/Capstone 2/Exe/chromedriver"
    
    def __init__(self):
        self.driver = webdriver.Chrome(executable_path = self.driver_path)
        
    def __del__(self):
        self.driver.close()
        
    def get_tweets(self, url, key_word):
        print("URL: \n    " + url)
        self.driver.get(url)
        print("TITLE: \n    " + self.driver.title)
        
        sec = 0
        while True:
            # break after 10 minutes
            if sec > 1000:
                break
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(10) # delay for 10 seconds
            sec += 10
                
        elements = self.driver.find_elements_by_class_name('js-tweet-text')
        tweets = [element.text for element in elements]
        
        return tweets

# %%
# Scraping tweets using twitter search API.
keyword = "movie"
start_date, end_date = "2018-06-01", "2018-09-07"
url = "https://twitter.com/search?q=" + keyword + "%20since%3A" + start_date + \
      "%20until%3A" + end_date + "&amp;amp;amp;amp;amp;amp;lang=tr%22"

scraper = Scraper()
tweets = scraper.get_tweets(url, keyword)
df = pd.DataFrame({'Tweets' : tweets})
# Out:
# URL:
#     https://twitter.com/search?q=movie%20since%3A2018-06-01%20until%3A2018-09-07&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     News about movie since:2018-06-01 until:2018-09-07 on Twitter

# %%
df.head(200)
# Out:
#                                                 Tweets
# 0    Burt Reynolds. True legend. Our hero. Funny as...
# 1    Just spent 5.99 on this movie and definitely w...
# 2    Im 19.  I get a few lines in a movie. The mega...
# 3    I want to warn you because nobody warned me: "...
# 4                I’ve never seen a Burt Reynolds movie
# 5    I want to watch a movie with my man tonight, c...
# 6    Experience everything it takes to be the first...
# 7    RT for a chance to win a pair of Poppy’s 3D gl...
# 8    The moment all Harry Potter fans lost it. Both...
# 9                     Watching @readyplayerone movie
# 10   #20MoreMovieChallenge\n\n1. Post a picture of ...
# 11   Me watchin dis movie #TheSnowman  Dis woz Not,...
# 12   This one's for the #movie buffs... but no chea...
# 13   This week we're counting down the very best DA...
# 14   In Spain 1968, my dad was filming 100 Rifles. ...
# 15   Sad for a professional woman to be chewing gum...
# 16   At His Best, Burt Reynolds Was a Great Actor, ...
# 17   #Win a Hoodie and Poster signed by Jennifer Ga...
# 18   Want to win an awesome prize pack and 4 VIP ti...
# 19   The 90’s were full of bad (ass) action flicks ...
# 20   I get extremely annoyed when people snap half ...
# 21   NEW VIDEO!!! "OUR WORST PRANK CALLS YET" with ...
# 22   Kevin Feige on why it took 10 years to get a f...
# 23           Peaky Blinders pic.twitter.com/u08wItRe5F
# 24   Ready Player One has def been one of my main g...
# 25   Even if you can’t get to Italy right now, you ...
# 26   this film is forever going to have a v special...
# 27   EXCLU: RUNAWAYS star @GreggSulkin reteams with...
# 28   I wish jaejong and taehwan would do a korean b...
# 29   Is there a master list someplace where I can s...
# ..                                                 ...
# 170  Don't make her angry. You wouldn't like her wh...
# 171  UPDATE: Jared Leto's Marvel Movie 'Morbius' Ey...
# 172  "Annabelle Creation" is a decently effective h...
# 173                 i need a scary movie marathon ASAP
# 174  Django Unchained deserved that huge silly hype...
# 175  Awkwafina needs to be in every single movie fr...
# 176  who has done more for the lgbt community \nrt ...
# 177           Iwannacuddleand watchspookymovieswithyou
# 178  “I was looking for you” \n\n“Well, now you fou...
# 179  Film > Zac Efron Reportedly The Top Choice To ...
# 180  Dumb hallowed movie trailer that probably won’...
# 181  au where cid and regis didn't fall out and cor...
# 182           Iwannacuddleand watchspookymovieswithyou
# 183  The only movie with the word black in it that ...
# 184  Sneak Peek for #AStarIsBorn  watch Ally sing #...
# 185  I grew up on Burt Reynolds movies.\nIt’s a sad...
# 186  TOM HOLLAND AND CHRIS EVANS ARE STARRING IN TH...
# 187  Him and Sally Fields has strong chemistry in t...
# 188  My very first attempt at a Thomas and Friends ...
# 189  Zack’s just chilling with his own movie theatr...
# 190  Pulse check... y’all still breathing because W...
# 191                              They are perfection!
# 192  It's the gift that keeps on giving. OMG so good!
# 193  did anyone else notice this? #AStarIsBorn\n\n(...
# 194                  Wow the new Nun movie looks good
# 195  We can’t help falling in love with the #CrazyR...
# 196  This YEEYEE needs a date for the nun movie tom...
# 197  i really hope the nun is actually a scary movi...
# 198  #stree is fantastic movie to watch!  Total pai...
# 199  CHRIS EVANS AND TOM HOLLAND IN AN UPCOMING MOV...
#
# [200 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961 entries, 0 to 1960
# Data columns (total 1 columns):
# Tweets    1961 non-null object
# dtypes: object(1)
# memory usage: 15.4+ KB

# %%
# Dump tweets to csv file for further analysis.
df.to_csv('../Data/tweets.csv', index = False)
