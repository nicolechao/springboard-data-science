# %% [markdown]
# # Data Scraping
#
# In this notebook we
# 1. Use Selenium & twitter search API to scrape twitter data.
# 2. Dump them in to a csv file for further analysis.

# %%
# Import packages
import pandas as pd
import json

# selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
# Define function for scraping tweets
class Scraper():
    driver_path = "/Users/Nicole/Courses/Springboard-data-science/Capstone 2/Exe/chromedriver"
    
    def __init__(self):
        self.driver = webdriver.Chrome(executable_path = self.driver_path)
        
    def __del__(self):
        self.driver.close()
        
    def get_tweets(self, url, key_word):
        print("URL: \n    " + url)
        self.driver.get(url)
        print("TITLE: \n    " + self.driver.title)
        
        sec = 0
        while True:
            # break after 10 minutes
            if sec > 1000:
                break
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(10) # delay for 10 seconds
            sec += 10
                
        elements = self.driver.find_elements_by_class_name('js-tweet-text')
        tweets = [element.text for element in elements]
        
        return tweets

# %%
# Scraping tweets using twitter search API.
# Define some keywords for searching.
keywords = ['movie', \
            'film', \
            'adrift', \
            'bookclub', \
            'thehappyprince', \
            'Oceans8', \
            'inthefade', \
            'crazyrichasians', \
            'jurassicworld', \
            'missionimpossible', \
            'mi6', \
            'americananimals', \
            'incredibles2', \
            'mammamia']

start_date, end_date = "2018-06-01", "2018-09-11"

dfs = []

for keyword in keywords:
    url = "https://twitter.com/search?q=" + keyword + "%20since%3A" + start_date + \
      "%20until%3A" + end_date + "&amp;amp;amp;amp;amp;amp;lang=tr%22"

    scraper = Scraper()
    tweets = scraper.get_tweets(url, keyword)
    
    df = pd.DataFrame({'Tweets' : tweets})
    dfs.append(df)
# Out:
# URL:
#     https://twitter.com/search?q=movie%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     News about movie since:2018-06-01 until:2018-09-11 on Twitter
# URL:
#     https://twitter.com/search?q=film%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     News about film since:2018-06-01 until:2018-09-11 on Twitter
# URL:
#     https://twitter.com/search?q=adrift%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     adrift since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=bookclub%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     bookclub since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=thehappyprince%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     thehappyprince since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=Oceans8%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     Oceans8 since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=inthefade%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     inthefade since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=crazyrichasians%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     crazyrichasians since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=jurassicworld%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     jurassicworld since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=missionimpossible%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     missionimpossible since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=mi6%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     News about mi6 since:2018-06-01 until:2018-09-11 on Twitter
# URL:
#     https://twitter.com/search?q=americananimals%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     americananimals since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=incredibles2%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     incredibles2 since:2018-06-01 until:2018-09-11 - Twitter Search
# URL:
#     https://twitter.com/search?q=mammamia%20since%3A2018-06-01%20until%3A2018-09-11&amp;amp;amp;amp;amp;amp;lang=tr%22
# TITLE:
#     mammamia since:2018-06-01 until:2018-09-11 - Twitter Search

# %%
for df in dfs:
    print(df.head(10))
    print(df.info())
# Out:
#                                               Tweets
# 0  I think there’s a first date going on near me ...
# 1  Sell all your houses. Stop flying private jets...
# 2  Starship Troopers (1997) is a deliciously ambi...
# 3  Then this & they never ran. I felt like I was ...
# 4                    Best Gary Oldman movie? (Pt. 2)
# 5  Find out how an unexpected practical effect br...
# 6  fauni just called me from jail and then he pas...
# 7  Jamie Dornan and Matt Bomer both stopped by a ...
# 8  Just saw that a Russian/South Korean team of s...
# 9  My brother, Benjamin Rice, engineered and co-p...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 1 columns):
# Tweets    2018 non-null object
# dtypes: object(1)
# memory usage: 15.8+ KB
# None
#                                               Tweets
# 0  I just had to block a handful of Trolls who se...
# 1  Max Minghella just told @MTV that Dylan O’Brie...
# 2  Find out how an unexpected practical effect br...
# 3  I do hope this isn't going to be a regular occ...
# 4  The best animals on film I've seen at #TIFF18 ...
# 5  Man, Film Twitter really hates The Nun and I m...
# 6  Congratulations to Francis Lee picking up @The...
# 7  ‘you’re wrong. go back and watch the first fil...
# 8  I can't get over this film, can't miss any cha...
# 9  I just had Douglas Murray and Dan Rusanowsky i...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 1 columns):
# Tweets    1989 non-null object
# dtypes: object(1)
# memory usage: 15.6+ KB
# None
#                                               Tweets
# 0  So glad that Les Moonves was set adrift after ...
# 1  This is what I’m looking for - a movie that ma...
# 2  not to get up in my feelings about marceline g...
# 3  #ScrapUniversalCredit \n\nI could give you a l...
# 4  In my early years \nI hid my tears\nPassing my...
# 5  Everyone go rent the movie #Adrift ! True stor...
# 6  Love can weather any storm. Shailene Woodley a...
# 7              Adrift is a must watch movie jud diay
# 8  unf spree not cus i want a skinny ratio or cus...
# 9  don’t watch the movie adrift unless u wanna so...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 1 columns):
# Tweets    59 non-null object
# dtypes: object(1)
# memory usage: 552.0+ bytes
# None
#                                               Tweets
# 0  what I *am* doing is taking note of everyone t...
# 1  CURRENTLY READING: Oranges are not the only fr...
# 2     A or B guys, what do you think?\n\n#bookclubs
# 3  This is a fanmade account. Because @wwbookclub...
# 4  I’m still too ill to go, but you could go! Get...
# 5  I NEED YOUR VOTE! So, there's going to be a pu...
# 6  Starting up this week, we are gonna do Philoso...
# 7  Always reading with my cats trying to start a ...
# 8  Twitter Fam, I have decided to ask a HUGE favo...
# 9  #WeAreFrozenbyte I started a #BookClub at the ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 1 columns):
# Tweets    692 non-null object
# dtypes: object(1)
# memory usage: 5.5+ KB
# None
#                                               Tweets
# 0  Bravo to my husband @Frédéric Delrue, #Brian M...
# 1  Double feature today: #TheHappyPrince and (if ...
# 2  #Fontanelle cemetery....\nMagic #Naples...\n#C...
# 3  Good night my friends, it's time for me to go ...
# 4  Have you seen #TheHappyPrince?\nWhat do you th...
# 5  Reminds me I must see #TheHappyPrince again so...
# 6  #TheHappyPrince is fast becoming a big film. #...
# 7  Colin speaks italian here...\n"Hai il petto e ...
# 8                    Rupert Everett #TheHappyPrince
# 9  Heartbreaking. Can't wait to watch. #TheHappyP...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
# Tweets    15 non-null object
# dtypes: object(1)
# memory usage: 200.0+ bytes
# None
#                                               Tweets
# 0  Getting to the bottom of it all and even getti...
# 1  A stellar cast, including #CateBlanchett, star...
# 2  Just watched #Oceans8 (I know, I’m a mom now, ...
# 3  See what the heist is about - watch the entire...
# 4  Come. To. Mama. \nOwn #Oceans8 on Blu-ray™ tom...
# 5  Vote for Ocean's 8 by retweeting this post: #O...
# 6  I think I found the shirt. #RichardArmitage #O...
# 7                Really wanna watch oceans8 real bad
# 8                       Ocean's 8 for #pcas #oceans8
# 9                        Smooth criminals  #Oceans8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 933 entries, 0 to 932
# Data columns (total 1 columns):
# Tweets    933 non-null object
# dtypes: object(1)
# memory usage: 7.4+ KB
# None
#                                               Tweets
# 0  she said she feels out of it and it's no wonde...
# 1  i just use this page when i want to do an adva...
# 2                                      have you read
# 3  ok, i had to close twitter and open it again. ...
# 4   You gotta admit, for the time ... not the worst?
# 5  ok i just got home from a busy day at work, wh...
# 6  Apparently it’s only 10, not 100. Though I’m n...
# 7  I love LOVE the foxing album and I'll say this...
# 8  under the redesign it redirects to twitter exp...
# 9  I got dilaudid after I broke my collarbone and...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 1 columns):
# Tweets    374 non-null object
# dtypes: object(1)
# memory usage: 3.0+ KB
# None
#                                               Tweets
# 0  My cover of “Can’t Help Falling In Love” from ...
# 1  Been hearing from some white viewers that CRAZ...
# 2  #Shadowhunters and #CrazyRichAsians star @harr...
# 3  Get yourself a love like this.  #CrazyRichAsians
# 4        About to watch Crazy Rich Asians!  #excited
# 5  More #CrazyRichAsians fan art? HELLS YEAH! Giv...
# 6  How many times have you seen #CrazyRichAsians?...
# 7  Don’t miss the movie that is capturing the wor...
# 8  #CrazyRichAsians is pure joy! Take your friend...
# 9  Seeing #CrazyRichAsians again with the BFF thi...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 1 columns):
# Tweets    1962 non-null object
# dtypes: object(1)
# memory usage: 15.4+ KB
# None
#                                               Tweets
# 0  CRAAAAWLING IN MY SKIIIIIIN\nTHESE WOOOUNDS TH...
# 1  Just finished this Jurassic Park series poster...
# 2  Which Jurassic World villain has the  worst pe...
# 3  Rate Jurassic Park and World Trilogies. #juras...
# 4  REXY!!! #JurassicPark #Jeep #JPFan #JurassicWo...
# 5  Fight no.1 Who would win in a fight? Rexy in h...
# 6  So, @ScumGame has zombies and robots... but on...
# 7  Here's an interesting question - did #Jurassic...
# 8  Coyote Pack! Did you hear our BIG announcement...
# 9  WIP Raptor picture\n#raptor #JurassicWorld #ve...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1964 entries, 0 to 1963
# Data columns (total 1 columns):
# Tweets    1964 non-null object
# dtypes: object(1)
# memory usage: 15.4+ KB
# None
#                                               Tweets
# 0  Mysterious rope has appeared at Greenwich Coun...
# 1  Sneaking some mid week uber eats through the b...
# 2  Yeah! The most recent was 'Mission Impossible'...
# 3  Vote for Tom Cruise from Mission Impossible: F...
# 4  The main reason audiences love Tom Cruise's 'M...
# 5  My brother got his hands on a printed draft of...
# 6  'Mission: Impossible - Fallout' crosses $700M ...
# 7  Getting ready for a very busy afternoon, inclu...
# 8  Fallout is my favorite Mission: Impossible mov...
# 9  The JT LEROY movie is in the IMAX theater for ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 1 columns):
# Tweets    426 non-null object
# dtypes: object(1)
# memory usage: 3.4+ KB
# None
#                                               Tweets
# 0  US state senator, decorated Vietnam veteran an...
# 1  Britain’s MI6 planning chemical attack in #Syr...
# 2  When Mossad meets KGB meets CIA meets RAW meet...
# 3  Wth! Virginia’s state Senator Richard Black me...
# 4  Jeremy #Corbyn received "a short intelligence ...
# 5  Here in Australia we have known Alexander Down...
# 6  Interesting story, MI6 might well have enginee...
# 7  Just paid a visit to MI6. Not for journalistic...
# 8  MI6 or GCHQ agents are effectively granted imm...
# 9  MI6 got real names and identities of Novichok ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 1 columns):
# Tweets    646 non-null object
# dtypes: object(1)
# memory usage: 5.1+ KB
# None
#                                               Tweets
# 0  It's been a while, but our four word film revi...
# 1  Are you in? Head on a heist with the #American...
# 2  Are you ready? @BartfromRaw is here to tell yo...
# 3  Watch it. It's brilliant. Sublime filmmaking. ...
# 4  #AmericanAnimals review: "Layton's hybrid styl...
# 5  So excited to see #AmericanAnimals this weekend.
# 6  Congratulations to @BartfromRaw for the outsta...
# 7  American Animals - An assured production with ...
# 8  AMERICAN ANIMALS: dead slow first act. Cinelit...
# 9  I absolute LOVED American Animals. Direction a...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 419 entries, 0 to 418
# Data columns (total 1 columns):
# Tweets    419 non-null object
# dtypes: object(1)
# memory usage: 3.4+ KB
# None
#                                               Tweets
# 0  Many of you have suggested we show what transp...
# 1  Jack-Jack is back-back! Bring #Incredibles2 ho...
# 2  Sometimes the most INCREDIBLE superheroes come...
# 3  Jack-Jack is back in theatres! See him in #Inc...
# 4  So after watching #Incredibles2 I came up with...
# 5  I’m still waiting for #Incredibles2 blu ray to...
# 6  #Incredibles2 has become the first animated fi...
# 7  The alternate suit Elastigirl is exclusive to ...
# 8  See #Incredibles2 again now showing during #La...
# 9  #MovieMath - #CrazyRichAsians enjoys its last ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 1 columns):
# Tweets    1490 non-null object
# dtypes: object(1)
# memory usage: 11.7+ KB
# None
#                                               Tweets
# 0  This couple in Halloween is about to have sex....
# 1  i just saw mamma mia 2 and \n1. i’m gay for li...
# 2  Dear future husband, I loveyou so much. May Go...
# 3  never\nhave\nsex\nor\na\nmasked\nserial\nkille...
# 4          I can’t wait for Mamma Mia 3, Tokyo Drift
# 5  my mamma mia mutuals unfollow when i tweet abo...
# 6  If @PierceBrosnan isn’t singing at my wedding ...
# 7  Hi guys..\nI got a retweet deal from @AyoLits ...
# 8  I feel like the entire mamma mia fandom is goi...
# 9                          It’s my 18 birthdayyyyyy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2015 entries, 0 to 2014
# Data columns (total 1 columns):
# Tweets    2015 non-null object
# dtypes: object(1)
# memory usage: 15.8+ KB
# None

# %%
df = pd.concat(dfs)
df.head(20)
# Out:
#                                                Tweets
# 0   I think there’s a first date going on near me ...
# 1   Sell all your houses. Stop flying private jets...
# 2   Starship Troopers (1997) is a deliciously ambi...
# 3   Then this & they never ran. I felt like I was ...
# 4                     Best Gary Oldman movie? (Pt. 2)
# 5   Find out how an unexpected practical effect br...
# 6   fauni just called me from jail and then he pas...
# 7   Jamie Dornan and Matt Bomer both stopped by a ...
# 8   Just saw that a Russian/South Korean team of s...
# 9   My brother, Benjamin Rice, engineered and co-p...
# 10  Slip your hand between my thighs and play with...
# 11                    best Boxing movie of all time
# 12  Greatest basketball movie is “ Glory Road” don...
# 13  Er, I'm closing in on 19K followers, many of w...
# 14               “What’s your favorite scary movie?”
# 15  Franchise experts: Is the new Halloween the fi...
# 16  Happy 58th Birthday #ColinFirth! \n\nWhat's yo...
# 17  I have never cried during a movie, im the best...
# 18  Y'all remember this movie ? @SAHipHopMagcoza @...
# 19  the craziest thing about 2 Girls 1 Cup is that...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15002 entries, 0 to 2014
# Data columns (total 1 columns):
# Tweets    15002 non-null object
# dtypes: object(1)
# memory usage: 234.4+ KB

# %%
# Dump tweets to csv file for further analysis.
df.to_csv('../Data/tweets.csv', index = False)
